# %% [markdown]
# <a href="https://colab.research.google.com/github/VHCUTC/data_science/blob/master/TD_Introduction_Python_Partie_I.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TD01 - Introduction au langage de programmation Python

# %% [markdown]
# ## **1. Introduction**
# **Python** est un langage interprété: lorsqu'on écrit une instruction, on peut directement l'exécuter. Un langage interprété permet de programmer plus facilement, de manière interactive, de tester facilement un morceau de code. C'est donc un langage idéal pour rapidement développer et tester des prototypes, ou plus particulièrement, des algorithmes d'analyse de données.
#
# * C'est un langage haut-niveau: une seule ligne de code permet dans certains cas de réaliser des processus complexe.
#
# * Python est open source: et donc gratuit pour tout le monde, y compris les entreprises.
#
# * C'est un langage populaire: la communauté de développeurs est très active, et on trouve facilement sur internet de la documentation et de très nombreux exemples d'utilisation dans tout type d'application.
#
# ![python_stack_overflow_withsource.png](data:image/png;base64,...)

# %% [markdown]
# **Jupyter Notebook**
#
# ![poll-top-python-ide-468.jpg](data:image/jpeg;base64,...)
#
# **Google Colab: La version cloud de Jupyter Notebook**
#
# Pour utiliser Google colab il suffit d’aller sur google drive ensuite cliquer sur nouveau ensuite sur “plus” et choisissez “Colaboratory”.
#
# Si vous n’avez pas l’option “Colaboratory” cliquez sur “Associer plus d’applications” puis rechercher “Colaboratory” et cliquez sur connecter.
#
# Vous pouvez aussi accéder directement à l’interface de google colab en utilisant ce lien https://colab.research.google.com/
#
# Google Colab est un environnement permettant d'exécuter directement un Notebook iPython. Un Notebook est une série de cellules de texte (comme celle que vous êtes en train de lire), ou de code Python. Les cellules de code sont interactives: lorsque vous les lancez, elles réalisent le script ligne par ligne, et renvoient directement les résultats en-dessous de la cellule.
#
# Pour exécuter une cellule de code, sélectionner la cellule et :
#
# appuyer sur le bouton ![Sans titre.png](data:image/png;base64,...)apparaissant à gauche ou utiliser le raccourcis Shift+Enter (ou Ctrl+Enter pour rester sur la cellule après exécution)

# %% [markdown]
# **Excercice 1. Premier programme en Python avec Google Colab**
#
# 1.   Créer un programme qui permet d'afficher les messages suivants : "TD01", "Introduction à Python" et "TD01 Introduction à Python". Pour faire ça :
# *   Créer un nouveau fichier : Fichier > Nouveau Notebook
# *   Ajouter une cellule code en utilisant les boutons de contrôle du menu principal:
# ![Texte alternatif…](https://raw.githubusercontent.com/titsitits/UNamur_Python_Analytics/master/Images/notebook0_image1.png)
# ou le menu apparaissant sous une cellule existante:
# ![Texte alternatif…](https://raw.githubusercontent.com/titsitits/UNamur_Python_Analytics/master/Images/notebook0_image2.png)
# * Utiliser la commande **print("le message")** pour afficher le message
# 2. Modifier le nom de votre fichier
# 3. Enregistrer votre fichier : Fichier > Enregistrer une copie dans Google Drive, Enregistrer une copie dans GitHub, Télécharger le fichier.ipynb, Télécharger le code .py
# 4. Fermer et ouvrir votre fichier
# 5. Partager votre fichier avec vos amis

# %%
x="TD01"
print(x)
print('Introduction à Python')
print(x+' Introduction à Python')
# Out:
# TD01
# Introduction à Python
# TD01 Introduction à Python

# %% [markdown]
# ## **2. Opérations de base**

# %% [markdown]
# ## **Types de données de base**
# On identifie généralement quatre types de données de base en Python.
#
# Trois sont des **données numériques**:
# * Booléen (**`bool`**): `True, False`
# * Nombre entier (**`int`**): `-42, 0, 1, 42, 250000`
# * Nombre décimal à virgule flottante (**`float`**): `42.0, 3.14, -0.01`
#
# La dernière permet de représenter du **texte**:
#
# * Chaîne de caractères (**`string`**): `"Hello World!"` ou `'Hello World!' `
#
# On définit un **`string`** en entourant le texte des symboles **"double quote"** ou **'simple quote'**. Ainsi, 4 représente un **`int`**, mais "4" représente un **`string`**.
#
# **Excercice 2. Types de données de base**
# 1.   Créer une varibale pour chaque type de variables précédent (4 types).
# 2.   Utiliser la commande ***type*** pour vérifier le type de chaque variable créée.
# 3. Convertir un spécifique type de variable vers un autre en utilisant les commandes suivantes : ***str, int, bool***
# 4. Utiliser la commande ***%whos*** pour afficher toutes les variables
#
# **Commentaire** : Ajouter des commentaires pour séparer la réponse de chaque question (e.g. Question 1, Question 2, Question 3). En Python, on insère un commentaire avec le caractère # (un dièse).

# %%
# Question 1
a=10
b=True
c=2.6
d="Bonjour"
# Question 2
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Question 3
print(int(b)) # convertir en entier
print(str(a)) # convertir en chaîne de caractères 
print(bool(c)) # convertir en booléen
# %whos
# Out:
# <class 'int'>
# <class 'bool'>
# <class 'float'>
# <class 'str'>
# 1
# 10
# True
# Variable   Type     Data/Info
# -----------------------------
# a          int      10
# b          bool     True
# c          float    2.6
# d          str      Bonjour

# %%
# %whos
# Out:
# Variable   Type     Data/Info
# -----------------------------
# a          int      10
# b          bool     True
# c          float    2.6
# d          str      Bonjour

# %% [markdown]
# ## **Opérations arithmétiques**
# **Excercice 3. Tester les opérations arithmétiques**
# 1.   Utiliser la commande a **opérateur** b
# 2.   Les valeurs de a et b sont choisies aléatoirement
# 3. Tester et identifier les opérations suivantes :  +, -, **\***, **/**, **\*\***, **%**.

# %%
print(2+3)
print(2-3)
print(2*3)
print(2/3)
print(2**3)
print(2%3)
# Out:
# 5
# -1
# 6
# 0.6666666666666666
# 8
# 2

# %% [markdown]
# ## **Opérations de tests et logiques**
# **Excercice 4. Proposer des exemples pour tester les opérations de tests et logiques**
# * Test d'égalité: ==
# * Test d'inégalité: !=
# * Test de supériorité et infériorité stricte: > et <
# * Inférieur/supérieur ou égal: <= et >=
# * and et or logique

# %%
print(2==5)
print(3!=1)
print(2>3)
print(3>=3)
x=(2>1) and (2>3)
print(x)
# Out:
# False
# True
# False
# True
# False

# %% [markdown]
# ## **3. Contrôle du flux des instructions**
# Certaines instructions permettent de contrôler le flux du code:
#
# * Les **conditions** permettent de réaliser un bloc d'instructions, ou de l'éviter, ou encore de choisir un bloc d'instructions parmi plusieurs.
# * Les **boucles** permettent de repasser plusieurs fois, de manière itérative, par le même bloc d'instructions
# * Pour différencier les différents blocs d'instructions, on utilise l'**indentation** (en utilisant des Tab, ou des Whitespace)
#
# En Python, l'indentation de chaque ligne de commande est donc très importante, puisque c'est elle qui définit le flux des instructions.

# %% [markdown]
# ## **Conditions**

# %%
# Exemple 
a = 42
condition = a == 43
if condition == True:  
  print("C'est vrai!")
if condition == False:
  print("C'est faux!")
# Out:
# C'est faux!

# %% [markdown]
# **Excercice 5.** Utiliser les conditions pour déterminer si un entier saisi par l'utilisateur est dans les intervalles [0,5] et [10, 15] ou pas et afficher les résultats correspondants.
#
# * Saisir un entier : x=int(input("Saisir une valeur : ? ")).
# * Utiliser les conditions if, elif, else pour déterminer si x est dans les intervalles ou pas.
# * Utiliser la commande print pour afficher les résultats.

# %%
x=int(input("Sisir un entier10: "))
if (x>=0 and x<=5):
  print("La valeur saisie est entre 0 et 5")
elif (x>=10) and (x<=15):
  print("La valeur saisie est entre 10 et 15")
else: 
  print("La valeur saisie n'est pas dans les intervalles testés")
# Out:
# Sisir un entier10: 6
# La valeur saisie n'est pas dans les intervalles testés

# %% [markdown]
# ## **Boucles**
# Les boucles permettent de définir un flux itératif d'instructions:
# * **`for variable in variable_set:`**: on exécute le bloc d'instructions itérativement sur un ensemble d'éléments

# %%
for i in range(1, 5):

  print("Je suis à l'itération", i)
# Out:
# Je suis à l'itération 1
# Je suis à l'itération 2
# Je suis à l'itération 3
# Je suis à l'itération 4

# %% [markdown]
# * **`while condition:`**: on éxécute le même bloc d'instructions itérativement tant qu'on respecte une condition

# %%
count = 0
while count < 5:
	print("Je suis dans une boucle while depuis " + str(count) + " itérations")
	count += 1
# Out:
# Je suis dans une boucle while depuis 0 itérations
# Je suis dans une boucle while depuis 1 itérations
# Je suis dans une boucle while depuis 2 itérations
# Je suis dans une boucle while depuis 3 itérations
# Je suis dans une boucle while depuis 4 itérations

# %% [markdown]
# **Remarque** : Attention à l'**indentation** et au symbole **":"** ! C'est le bloc indenté après le symbole ":" qui dépend de la condition

# %% [markdown]
# **Excercice 6.** Utiliser les boucles pour calculer  $ y =\sum_{k=0}^{n} k^2$ avec $n$ est saisie par l’utilisateur.

# %%
# la solution avec for
n=input("Saisir n: ")
y=0
for k in range(0,6): 
  y+= k*k
print("y calculée par la boucle For est : " + str(y)) 
# la solution avec while
k=0
y=0
while k<=5:
  y+= k*k
  k+=1
  
print("y calculée par la boucle while est : " + str(y))
# Out:
# Saisir n: 5
# y calculée par la boucle For est : 55
# y calculée par la boucle while est : 55

# %% [markdown]
# ## **4. Les fonctions**
# Une fonction est une suite d'instructions que l'on peut appeler avec un nom.

# %%
#C'est une fonction qui permet de calculer y avec n saisie par l'utilisateur
def calcul_de_y(n):
  y=0
  for k in range(0,6): 
    y+= k*k
  return y

# %%
calcul_de_y(5)
# Out:
# 55

# %% [markdown]
# **Excercice 7.** Definir une fonction qui permet de calculer $ y =\sum x_k^2$ où les valeurs $x_k$ sont saisies par l'utilisateur sous la forme une liste des valeurs.
#
# Définir une fonction avec l'entrée étant une liste à l'aide l'instruction suivante: def nom_de_la_fonction(*nom_de_la_liste):

# %%
def calcul_de_y(*listX):
  y=0
  for k in range(0,len(listX)): 
    y+=listX[k]*listX[k]
  return y

# %%
calcul_de_y(1,3,5)
# Out:
# 35

# %% [markdown]
# **Remarques :**
#
#
# *   Dès son lancement, l’interpréteur Python met à disposition du développeur plusieurs fonctions natives (built-in functions en anglais), comme la fonction print(), abs(), min(), max(), round(), etc.
# *    Lorsque l'on regroupe des fonctions dans un fichier on crée un ensemble de fonctions que l'on nomme " module " (e.g. random, math, sys).
# *   Lorsque l'on cherche à regrouper des modules, on parle de package (Numpy, Panda, Scikit-learn, Tensorflow, etc)

# %% [markdown]
# ## **5. Structure des données (Data structure)**
# ![EWokjOaXgAI5fQI.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Excercice 8.**
#
# Pour chaque type de données (objet) :
#
#
# 1.   Créer un exemple
# 2.   Vérifier si les doublons sont autorisés ou pas
# 3.   Accéder à un ou plusieurs élément
# 4.   Vérifier si les modifications des éléments sont possibles
# 5.   Ajouter/supprimer des éléments, Min/Max, etc.
#
# **Remarque** : Activer le mode "Outils-->Paramètres-->Editeur--> Déclencher automatiquement les suggestions de code" puis Ctrl-space pour afficher les suggestions
